# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ["API_KEY"])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_da3de80df2e64f10888663305e4f230e',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使用する際には、いくつかの重要なポイントがあります。以下に主なポイントを挙げます。\n\n1. **目的の明確化**: 言語モデルを使用する目的を明確にすることが重要です。例えば、テキスト生成、質問応答、翻訳、要約など、目的に応じた使い方を考えます。\n\n2. **入力の質**: モデルに与える入力（プロンプト）を工夫することで、出力の質が大きく変わります。明確かつ具体的な指示を与えると、より良い結果が得られます。\n\n3. **コンテキストの提供**: モデルは与えられたコンテキストを基に応答しますので、必要な背景情報を提供することが重要です。特に長いテキストや複雑なテーマの場合、適切なコンテキストを設定することが求められます。\n\n4. **検証と評価**: モデルが生成した出力の正確性や妥当性を検証することが重要です。特に、専門的な情報やクリティカルな決定に関わる場合は、信頼性の高い情報源と照らし合わせる必要があります。\n\n5. **バイアスの認識**: 言語モデルは訓練データに基づいているため、バイアスが含まれる場合があります。そのため、出力を鵜呑みにせず、バイアスを意識することが重要です。\n\n6. **フィードバックの活用**: モデルの出力に対してフィードバックを与えることで、より良い応答を引き出すことができます。反復的なやり取りを通じて、求める情報に近づける努力が重要です。\n\n7. **倫理的な配慮**: モデルの利用に際しては、プライバシーや著作権、倫理に関する配慮が必要です。他者の権利を尊重し、適切に利用することが求められます。\n\nこれらのポイントを考慮することで、言語モデルをより効果的に活用することができます。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1776241865,
#  'id': 'chatcmpl-DUpwH1SqaYVT5A45kkjjgvslCQXQC',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_a7190374f3',
#  'usage': CompletionUsage(completion_tokens=524, prompt_tokens=18, total_tokens=542, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを使用する際には、いくつかの重要なポイントがあります。以下に主なポイントを挙げます。
#
# 1. **目的の明確化**: 言語モデルを使用する目的を明確にすることが重要です。例えば、テキスト生成、質問応答、翻訳、要約など、目的に応じた使い方を考えます。
#
# 2. **入力の質**: モデルに与える入力（プロンプト）を工夫することで、出力の質が大きく変わります。明確かつ具体的な指示を与えると、より良い結果が得られます。
#
# 3. **コンテキストの提供**: モデルは与えられたコンテキストを基に応答しますので、必要な背景情報を提供することが重要です。特に長いテキストや複雑なテーマの場合、適切なコンテキストを設定することが求められます。
#
# 4. **検証と評価**: モデルが生成した出力の正確性や妥当性を検証することが重要です。特に、専門的な情報やクリティカルな決定に関わる場合は、信頼性の高い情報源と照らし合わせる必要があります。
#
# 5. **バイアスの認識**: 言語モデルは訓練データに基づいているため、バイアスが含まれる場合があります。そのため、出力を鵜呑みにせず、バイアスを意識することが重要です。
#
# 6. **フィードバックの活用**: モデルの出力に対してフィードバックを与えることで、より良い応答を引き出すことができます。反復的なやり取りを通じて、求める情報に近づける努力が重要です。
#
# 7. **倫理的な配慮**: モデルの利用に際しては、プライバシーや著作権、倫理に関する配慮が必要です。他者の権利を尊重し、適切に利用することが求められます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができます。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けて効果的なマーケティング戦略を構築するには、以下のステップを考慮すると良いでしょう。
#
# ### 1. マーケットリサーチ
# - **ターゲット市場の特定**: 新製品がどの顧客層に向けられているのかを分析します。年齢、性別、趣味、ライフスタイル、購買行動などを考慮します。
# - **競合分析**: 同様の製品を提供している競合他社を調査し、彼らの強みや弱みを把握します。
#
# ### 2. 製品ポジショニング
# - **ユニークセリングプロポジション (USP)**: 新製品の特徴や利点を明確にし、競合製品との差別化を図ります。顧客に何を提供できるのかを明らかにします。
#
# ### 3. マーケティングプランの策定
# - **ブランディング**: 新製品の名称やロゴ、パッケージデザインを決定し、一貫性のあるブランドメッセージを作成します。
# - **プロモーション計画**: SNS、広告、PRイベント、インフルエンサーの活用など、どのメディアを通じて製品を宣伝するかを決めます。
#
# ### 4. 事前プロモーション
# - **ティーザーキャンペーン**: 新製品の発売前に興味を引くためのティーザーキャンペーンを行います。これにより、顧客の関心を高めます。
# - **先行予約**: 発売前に先行予約を受け付けることで、初期の売上を確保します。
#
# ### 5. 発売イベントの開催
# - **ローンチイベント**: 新製品の発表を盛大に行い、メディアやインフルエンサーを招待します。実際に製品を体験してもらい、リアルな反応を得ることが重要です。
# - **オンラインウェビナー**: オンラインでのトークイベントを開催し、製品の特長や使用方法を紹介します。
#
# ### 6. フィードバックの収集
# - **顧客の声を聞く**: 購入者からのフィードバックを収集し、製品の改善や次回のマーケティング戦略に活かします。SNS上やアンケートツールを活用するのが効果的です。
#
# ### 7. 継続的なマーケティング
# - **リターゲティング広告**: ウェブサイトを訪れたが購入に至らなかった顧客をターゲットにした広告を出すことで、再度興味を引きます。
# - **顧客維持施策**: 製品購入後のフォローアップメールやクーポンの提供などを通じて、リピート購入を促します。
#
# ### 8. 成果分析
# - **KPIの設定と評価**: 売上、サイト訪問数、SNSのエンゲージメントなどの指標を設定し、キャンペーンの成功を定期的に分析します。
#
# これらのステップを踏むことで、新製品の発売を成功に導く効果的なマーケティング戦略を構築できます。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n=3,  # 3回答を得る
    max_completion_tokens=100,  # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本はその多様性と独自の文化財によって、国内外から多くの人々が訪れる魅力的な国です。以下に、日本の魅力をいくつか紹介します。
#
# 1. **文化と歴史**:
#    - 日本は古代からの歴史を持ち、京都や奈良など古都には多くの歴史的な名所が点在しています。松尾大社や
# --------------------
# 日本には独自の文化、吸引力のある歴史、美しい自然など、多くの魅力があります。ここではいくつか의ポイントを紹介します！
#
# 1. **伝統文化**: 日本の伝統文化は非常に深く、茶道、折り紙、書道、歌舞伎、新年の習慣や祝祭など、さまざまな文化があります。特に和服や能、屋台などは
# --------------------
# もちろんです！日本は豊かな文化と歴史、魅力的な自然、そして進化した技術を兼ね備えた国です。以下は、日本の多様な魅力のいくつかです。
#
# ### 1. **美しい自然**
# 日本には四季折々の美しい自然があります。春の桜や秋の紅葉、夏の海や冬の雪景色など、それぞれの季節に合わせた風

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=0.0,
    n=3,  # 3回答を得る
    max_completion_tokens=100,  # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然の美しさが融合した魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を体験できる素晴らしい機
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる祭りは、地域の伝統や文化を体験できる貴重な機会です。例えば、京都の祇園祭や青森のねぶた祭り
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる祭りは、地域の伝統や文化を体験できる貴重な機会です。例えば、京都の祇園祭や青森のねぶた祭り

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n=3,  # 3回答を得る
    max_completion_tokens=100,  # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろん、日本の魅力をいくつかご紹介します！
#
# 1. **文化と歴史**:
#    - 日本は長い歴史を持ち、古い神社や寺、伝統的な町並みが残っています。京都や奈良の古い町並み、金閣寺や清水寺などの歴史的建造物は多くの観光客を魅了します。
#
# 2. **自然の美**:
# --------------------
# 日本には多くの魅力がありますので、いくつかのポイントを紹介しますね。
#
# 1. **豊かな文化と歴史**:
#    日本は長い歴史を持ち、古代からの伝統と文化が色濃く残っています。古い神社やお寺、美しい伝統的な建築が多く、歴史を感じることができます。
#
# 2. **四季の美**:
#    日本の四
# --------------------
# 日本はその多様な文化、歴史、自然の美しさ、そして食文化など、さまざまな魅力を持つ国です。以下は、日本の魅力をいくつか紹介します。
#
# 1. **歴史と文化**:
#    - 日本は長い歴史を持つ国で、古代からの伝統や文化が色濃く残っています。京都や奈良などの古都では、歴史

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    # 同じ単語を使用するかどうかを制御（2.0 を指定して、同じ単語が選ばれないようにした結果）
    presence_penalty=2.0,
    n=3,  # 3回答を得る
    max_completion_tokens=100,  # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかご紹介します。
#
# 1. **文化と伝統**: 日本は茶道や花道、武道など豊かな伝統文化を持っています。年中行事も多く、正月や桜の季節、お盆など特別なイベントがそれぞれの地域で祝われます。
#
# 2. **自然美**: 四季折々の風景が楽し
# --------------------
# もちろんです！日本は多様な文化、歴史、自然が融合した魅力的な国です。以下にいくつかの主な魅力を紹介します。
#
# ### 1. 歴史と伝統
# - **寺社仏閣**: 京都や奈良には数百年の歴史を持つ神社や寺院があります。特に金閣寺や清水寺などは訪れる価値があります。
# -
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 自然の美
# 日本は四季があり、それぞれの季節に異なる自然美を楽しむことができます。春には桜、夏には緑豊かな山々、秋には紅葉、冬には雪景色が広がります。また、日本各地には美しい温泉地や絶景スポットも

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME)  # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    # logit_bias = {95839:8, 3393:8} で、トークンID 95839 と 3393 に強いバイアス（8）をかけています。
    # これにより、これらのトークンが応答に含まれる可能性が高くなります。
    logit_bias={95839: 8, 3393: 8},
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！Aさん、お元気でしたか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確なプロンプト**: モデルに与える指示や質問は具体的で明確にすることが重要です。曖昧な表現だと期待する答えが得られないことがあります。
#
# 2. **文脈の提供**: 必要に応じて文脈や背景情報を提供すると、モデルがより適切な応答を生成しやすくなります。
#
# 3. **フィードバックの活用**: 出力に対してフィードバックを行い、 modelの生成結果を改善するために、プロンプトを調整することが有効です。
#
# 4. **バイアスと限界の理解**: モデルには限界やバイアスが存在します。そのため、生成された情報は常に批判的に検討し、必要に応じて他の情報源と照らし合わせることが重要です。
#
# 5. **利用目的の明確化**: モデルの利用目的を明確にし、それに応じた適切なプロンプトや質問を設定することで、より良い結果を得ることができます。
#
# 6. **多様な視点を取り入れる**: モデルに様々な視点からの質問を投げかけることで、より多様な情報を引き出すことができます。
#
# 7. **プライバシーとセキュリティの考慮**: 個人情報や機密情報を扱う際には、プライバシーとセキュリティに注意が必要です。無闇に情報を共有しないようにしましょう。
#
# これらのポイントに留意することで、言語モデルをより効果的に活用できるでしょう。
