# %%
print("Hello! World!")
# Out:
# Hello! World!

# %% [markdown]
# # レッスン0
#
# - VS Codeの基本的な書き方

# %% [markdown]
# **太字**　*斜体*　***太字かつ斜体***
#
# - 項目1
# - 項目2
#   - サブ項目
#
# 1. 項目1
# 2. 項目2
#
# ---
#
# | 見出し1 | 見出し2 |
# | ------- | ------- |
# | データ1 | データ2 |
# | データ3 | データ4 |
