# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

# 環境変数の取得
load_dotenv()

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ["API_KEY"])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# 1. Excelファイルを読み込む
df = pd.read_excel("サンプルデータ.xlsx", sheet_name="売上データ")
# データフレームを表示して確認
df.head()
# Out:
#   カテゴリー  商品コード   商品名        売上日    単価   数量    原価
# 0    食品   1001   りんご 2023-01-01   200   50   120
# 1    食品   1002   バナナ 2023-01-01   150  100    80
# 2    食品   1003    牛乳 2023-01-02   180   80   100
# 3    衣服   2001  Tシャツ 2023-01-02  1500   20   800
# 4    衣服   2002  ジーンズ 2023-01-03  5000   10  2500

# %%
# 2. データをLLM用にテキスト形式に変換
# データフレーム全体を文字列に変換
sales_data_text = df.astype(str)
prompt_text = (
    f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"
)
# 表示して確認
print(prompt_text)
# Out:
# 売上データ:
#     カテゴリー 商品コード      商品名         売上日    単価   数量    原価
# 0      食品  1001      りんご  2023-01-01   200   50   120
# 1      食品  1002      バナナ  2023-01-01   150  100    80
# 2      食品  1003       牛乳  2023-01-02   180   80   100
# 3      衣服  2001     Tシャツ  2023-01-02  1500   20   800
# 4      衣服  2002     ジーンズ  2023-01-03  5000   10  2500
# ..    ...   ...      ...         ...   ...  ...   ...
# 235    衣服  2077   レインパンツ  2023-04-28  2000   18  1000
# 236    食品  1085      ザクロ  2023-04-29   600   40   300
# 237   日用品  3077    バスブラシ  2023-04-29   400   60   200
# 238    衣服  2078  レインシューズ  2023-04-30  2500   15  1250
# 239    食品  1086    ココナッツ  2023-04-30   300   80   150
#
# [240 rows x 7 columns]
# この売上データの傾向を分析してください。

# %%
# 3. OpenAI APIの呼び出し

# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# LLMからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 売上データを分析することで、商品のパフォーマンスやカテゴリー別の傾向を把握できます。以下は、いくつかの主要な分析ポイントとインサイトです。
#
# ### 1. カテゴリー別売上比較
# 各カテゴリー（食品、衣服、日用品）の売上合計を算出し、どのカテゴリーが最も貢献しているかを分析します。
#
# #### 例:
# - 食品の売上合計
# - 衣服の売上合計
# - 日用品の売上合計
#
# ### 2. 商品別売上分析
# 各商品の売上（単価 × 数量）を計算し、売上が高い商品や低い商品を特定します。この情報は、プロモーションや在庫戦略に役立てることができます。
#
# #### 例:
# - 売上が高い商品トップ5
# - 売上が低い商品トップ5
#
# ### 3. 利益分析
# 利益は「売上 - 原価」で算出できます。利益が高い商品や低い商品を特定し、価格戦略や原価管理の調整に役立てます。
#
# ### 4. 売上トレンドの時間的変化
# 売上データの時間（売上日）を基に、特定の期間の売上トレンドをビジュアライズします。これにより、季節効果や特定のイベントによる売上の変化を把握できます。
#
# ### 5. 商品の販売数量と単価の関係
# 商品の販売数量と単価の相関関係を分析し、価格設定戦略に関するインサイトを得ることができます。たとえば、価格を上げた際の販売数量の変化を分析します。
#
# ### 6. マージン分析
# 各商品のマージン（(売上 - 原価) / 売上）を計算し、どの商品の利益率が良いかを把握します。利益率の高い商品にリソースを集中させる戦略を立てることができます。
#
# ### 7. 定期的な購入パターンの特定
# 売上データを通じて、特定の商品を定期的に購入する顧客のパターンや周期性を分析します。これにより、リピート購入促進の施策を考えることが可能です。
#
# ### まとめ
# これらの分析から得られるスチュエーションに基づいて、効果的なマーケティング戦略を立てることができます。具体的な数値分析を行うことで、よりデータに基づいた意思決定が可能になります。次のステップとしては、実際のデータを用いて上記の分析を行い、具体的な数値やインサイトを抽出し、可視化することが推奨されます。

# %%
# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=["結果"])
print(df_out)
# Out:
#                                                    結果
# 0   売上データを分析することで、商品のパフォーマンスやカテゴリー別の傾向を把握できます。以下は、...
# 1
# 2                                   ### 1. カテゴリー別売上比較
# 3   各カテゴリー（食品、衣服、日用品）の売上合計を算出し、どのカテゴリーが最も貢献しているかを分...
# 4
# 5                                             #### 例:
# 6                                           - 食品の売上合計
# 7                                           - 衣服の売上合計
# 8                                          - 日用品の売上合計
# 9
# 10                                     ### 2. 商品別売上分析
# 11  各商品の売上（単価 × 数量）を計算し、売上が高い商品や低い商品を特定します。この情報は、プ...
# 12
# 13                                            #### 例:
# 14                                      - 売上が高い商品トップ5
# 15                                      - 売上が低い商品トップ5
# 16
# 17                                        ### 3. 利益分析
# 18  利益は「売上 - 原価」で算出できます。利益が高い商品や低い商品を特定し、価格戦略や原価管理...
# 19
# 20                                ### 4. 売上トレンドの時間的変化
# 21  売上データの時間（売上日）を基に、特定の期間の売上トレンドをビジュアライズします。これにより...
# 22
# 23                               ### 5. 商品の販売数量と単価の関係
# 24  商品の販売数量と単価の相関関係を分析し、価格設定戦略に関するインサイトを得ることができます。...
# 25
# 26                                      ### 6. マージン分析
# 27  各商品のマージン（(売上 - 原価) / 売上）を計算し、どの商品の利益率が良いかを把握しま...
# 28
# 29                               ### 7. 定期的な購入パターンの特定
# 30  売上データを通じて、特定の商品を定期的に購入する顧客のパターンや周期性を分析します。これによ...
# 31
# 32                                            ### まとめ
# 33  これらの分析から得られるスチュエーションに基づいて、効果的なマーケティング戦略を立てることが...

# %%
# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)

# %%
# ワークフロー化
print("処理を開始します。")

# 1. Excelファイルを読み込む
df = pd.read_excel("サンプルデータ.xlsx", sheet_name="売上データ")

# 2. データをLLM用にテキスト形式に変換
sales_data_text = df.astype(str)
prompt_text = (
    f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"
)

# 3. OpenAI APIの呼び出し
# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"
# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=["結果"])

# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)

print("Excelファイルに分析結果を保存しました。")
# Out:
# 処理を開始します。
# Excelファイルに分析結果を保存しました。
